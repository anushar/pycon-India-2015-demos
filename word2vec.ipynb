# %%
import gensim as gn

# %%
sen = gn.models.word2vec.Text8Corpus('../lib/data/text8')

# %%
sen.max_sentence_length
# Out:
# 1000

# %%
sen.fname
# Out:
# '../lib/data/text8'

# %%
model = gn.models.word2vec.Word2Vec(sen,size=100, window=5, min_count=5, workers=4)
# Out:
# /Users/grabhouse/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/gensim/models/word2vec.py:636: UserWarning: C extension not loaded for Word2Vec, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   warnings.warn("C extension not loaded for Word2Vec, training will be slow. "

# %%
model['very']
# Out:
# array([ -4.13691532e-03,  -4.51100897e-03,  -1.00752327e-03,
#          1.32083206e-03,  -1.73049967e-03,  -1.84739963e-03,
#          4.72979201e-03,  -1.19771995e-03,  -2.94309761e-03,
#         -8.34387203e-04,  -3.11175827e-03,   4.69772751e-03,
#          7.75096763e-04,   1.56590156e-03,   1.39127462e-03,
#         -1.42550934e-03,   3.34495516e-03,   4.36279876e-03,
#         -3.15276906e-03,  -3.55481682e-03,   2.74069281e-03,
#         -3.87653592e-03,   1.45075179e-03,   2.44096830e-03,
#          3.25533259e-03,   1.66793715e-03,   4.61210357e-03,
#          8.61944209e-05,   5.85386762e-04,   4.22265753e-03,
#         -3.41697800e-04,   3.69536411e-03,  -3.31073604e-03,
#          3.91209731e-03,   2.20974977e-03,   1.73076789e-03,
#          3.83902760e-03,   2.79186061e-03,   1.45312143e-03,
#         -3.53308744e-03,  -2.50833342e-04,  -7.82932853e-04,
#          4.21697553e-03,  -4.79509961e-03,   3.98547156e-04,
# ...

# %%
model.most_similar(positive = ['very'])
# Out:
# [(u'holomorphic', 0.4153335392475128),
#  (u'unloading', 0.4085887372493744),
#  (u'kleiner', 0.39887428283691406),
#  (u'douche', 0.3881288766860962),
#  (u'goldstone', 0.38335201144218445),
#  (u'patriarchate', 0.37743404507637024),
#  (u'flap', 0.3699076473712921),
#  (u'lakefront', 0.3542691469192505),
#  (u'concurrent', 0.34884577989578247),
#  (u'impending', 0.3459141254425049)]

# %%
model.most_similar(['city'])
# Out:
# [(u'hmmwv', 0.40063491463661194),
#  (u'riddler', 0.382533460855484),
#  (u'mountaineering', 0.38198351860046387),
#  (u'urals', 0.38162192702293396),
#  (u'characteristics', 0.3812839388847351),
#  (u'enthusiastically', 0.37574997544288635),
#  (u'shrapnel', 0.3756416440010071),
#  (u'manhood', 0.37093794345855713),
#  (u'malebranche', 0.3694401979446411),
#  (u'carbonate', 0.36902403831481934)]
